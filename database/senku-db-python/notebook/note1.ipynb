# %%
cd ../
# Out:
# /Users/hirotosuzuki/Workspace/Senku/database/senku-db-python

# %%
from db.database import Database

# %%
db = Database()

print(db.execute("CREATE TABLE users (id INT, name TEXT)"))
# "Table users created."

print(db.execute("INSERT INTO users VALUES (1, 'Alice')"))
# "Inserted into users."

print(db.execute("SELECT * FROM users"))
# [['1', 'Alice']]
# Out:
# Table USERS created.
# Inserted into USERS.
# [['1', 'ALICE']]
